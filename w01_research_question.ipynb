# %% [markdown]
# <a href="https://colab.research.google.com/github/rubabamjad4/flyrank-ml-internship/blob/main/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# # 1. My Lane (or Freestyle) and Why
#
# I chose the Content Ranking/SEO lane because it focuses on improving how content is ranked and presented to users. This is an interesting machine learning problem since content performance depends on many factors, such as relevance, user engagement, and search behavior. By applying machine learning, we can identify patterns that help rank content more effectively and support better decisions about which content should be promoted or optimized.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# Decision framing

decision = "Rank and prioritize content"
decision_maker = "SEO specialist / Content team"
action = "Promote or optimize high-performing content"
cost_of_wrong_call = "Lower engagement, fewer clicks, and reduced website traffic"

print("Decision:", decision)
print("Decision Maker:", decision_maker)
print("Action:", action)
print("Cost of Wrong Recommendation:", cost_of_wrong_call)
# Out:
# Decision: Rank and prioritize content
# Decision Maker: SEO specialist / Content team
# Action: Promote or optimize high-performing content
# Cost of Wrong Recommendation: Lower engagement, fewer clicks, and reduced website traffic

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("/content/starter_data.csv")

# Display the first few rows
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_7449/3060408753.py in <cell line: 0>()
#       2
#       3 # Load the dataset
# ----> 4 df = pd.read_csv("/content/starter_data.csv")
#       5
#       6 # Display the first few rows
#
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## Careful Words: What I Can and Can't Claim
#
# This project uses observed historical data to identify patterns that may help rank or prioritize content. The results are intended to support decision-making by content and SEO teams. Any recommendations should be treated as directional guidance rather than guaranteed outcomes.
#
# This project does **not** prove that one factor causes better content performance, and it cannot predict Google's ranking algorithm or future search results with certainty. The model provides decision-support based on the available data, not causal proof or guaranteed predictions.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
